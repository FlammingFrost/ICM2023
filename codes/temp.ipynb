# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_excel('./附件.xlsx')
data.shape
# Out:
# (1745, 2)

# %%
# plot in xy plane
import matplotlib.pyplot as plt

plt.scatter(data['x坐标 (m)'], data['y坐标 (m)'],s=1)

# %%
#draw a square at each point, length = 6m
plt.figure(figsize=(10,10),dpi=200)
for i in range(data.shape[0]):
    x = data['x坐标 (m)'][i]
    y = data['y坐标 (m)'][i]
    plt.plot([x-3,x+3],[y+3,y+3],color='black')
    plt.plot([x-3,x+3],[y-3,y-3],color='black')
    plt.plot([x-3,x-3],[y-3,y+3],color='black')
    plt.plot([x+3,x+3],[y-3,y+3],color='black')

for i in range(data.shape[0]):
    if data['x坐标 (m)'][i] <10 and data['y坐标 (m)'][i] < -300 and data['x坐标 (m)'][i] >-10:
        print(data['x坐标 (m)'][i],data['y坐标 (m)'][i])
        x = data['x坐标 (m)'][i]
        y = data['y坐标 (m)'][i]
        plt.plot([x-3,x+3],[y+3,y+3],color='r')
        plt.plot([x-3,x+3],[y-3,y-3],color='r')
        plt.plot([x-3,x-3],[y-3,y+3],color='r')
        plt.plot([x+3,x+3],[y-3,y+3],color='r')

plt.show()
# Out:
# 4.236 -310.133
# -3.881 -323.623
# -4.105 -337.107

# %%
# Out:
# 4.236 -310.133
# -3.881 -323.623
# -4.105 -337.107

# %%
import wandb
import random

# start a new wandb run to track this script
wandb.init(
    # set the wandb project where this run will be logged
    project="ICM2023-GD",
    
    # track hyperparameters and run metadata
    config={
    "learning_rate": 0.02,
    "architecture": "CNN",
    "dataset": "CIFAR-100",
    "epochs": 10,
    }
)

# simulate training
epochs = 10
offset = random.random() / 5
for epoch in range(2, epochs):
    acc = 1 - 2 ** -epoch - random.random() / epoch - offset
    loss = 2 ** -epoch + random.random() / epoch + offset
    
    # log metrics to wandb
    wandb.log({"acc": acc, "loss": loss})
    
# [optional] finish the wandb run, necessary in notebooks
wandb.finish()
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: flammingfrost. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.15.10
# Run data is saved locally in <code>e:\Project\2023-09-08 ICM\codes\wandb\run-20230909_171404-p1r2h4bx</code>
# Syncing run <strong><a href='https://wandb.ai/flammingfrost/ICM2023-GD/runs/p1r2h4bx' target="_blank">sparkling-disco-1</a></strong> to <a href='https://wandb.ai/flammingfrost/ICM2023-GD' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/flammingfrost/ICM2023-GD' target="_blank">https://wandb.ai/flammingfrost/ICM2023-GD</a>
#  View run at <a href='https://wandb.ai/flammingfrost/ICM2023-GD/runs/p1r2h4bx' target="_blank">https://wandb.ai/flammingfrost/ICM2023-GD/runs/p1r2h4bx</a>
# ...
